# %%
#Lib/collections/__init__.py

#from collections import * 
from collections import ChainMap 


#ChainMap

baseline = {'music': 'bach', 'art': 'rembrandt'}
adjustments = {'art':'van gogh', 'opera': 'carmen'}

list(ChainMap(adjustments, baseline))

# %%
combined = baseline.copy()
combined.update(adjustments)
list(combined)

for i in combined.keys():
    print(i)
print('\n')
for i in combined.values():
    print(i)

# %%
import builtins
pylookup = ChainMap(locals(), globals(), vars(builtins))
print(pylookup)
# Out:
# ChainMap({'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', "#Lib/collections/__init__.py\n\n#ChainMap\n\nbaseline = ['music': 'bach', 'art':'rembrandt']\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\nimport collections\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\nimport collections\n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\nfrom collections\n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\nfrom collections import * \n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\n#from collections import * \nimport ChainMap \n\n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", "#Lib/collections/__init__.py\n\n#from collections import * \nfrom collections import ChainMap \n\n\n#ChainMap\n\nbaseline = {'music': 'bach', 'art': 'rembrandt'}\nadjustments = {'art':'van gogh', 'opera': 'carmen'}\n\nlist(ChainMap(adjustments, baseline))", 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined.key())', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined).keys()', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nprint(combined)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nprint(combined.keys())', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nprint(combined.values())', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nfor i in combined.keys()\nprint(i)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nfor i in combined.keys():\n    print(i)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nfor i in combined.values():\n    print(i)', 'combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nfor i in combined.keys():\n    print(i)\n    \nfor i in combined.values():\n    print(i)', "combined = baseline.copy()\ncombined.update(adjustments)\nlist(combined)\n\nfor i in combined.keys():\n    print(i)\nprint('\\n')\nfor i in combined.values():\n    print(i)", 'import builtins', 'import builtins\n    pylookup = ChainMap(locals(), globals(), vars(builtins))', 'import builtins\npylookup = ChainMap(locals(), globals(), vars(builtins))', 'import builtins\npylookup = ChainMap(locals(), globals(), vars(builtins))\nprint(pylookup)'], '_oh': {6: ['music', 'art', 'opera'], 8: ['music', 'art', 'opera'], 9: ['music', 'art', 'opera'], 10: ['music', 'art', 'opera'], 13: ['music', 'art', 'opera']}, '_dh': ['/data1/py_place/code-template/python'], 'In': ['', "#Lib/collections/__init__.py\n\n#ChainMap\n\nbaseline = ['music': 'bach', 'art':'rembrandt']\nadj ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., '__IPYTHON__': True, 'display': <function display at 0x7fad1af75dd0>, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fad19ceae90>>})
